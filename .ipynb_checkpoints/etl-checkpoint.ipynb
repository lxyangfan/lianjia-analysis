# %%
#-*- encoding:utf-8 -*-
import pandas as pd
import json

# %%
dict_list_file = "data/preowened-2017-06-30.json"
dict_list = None
with open(dict_list_file) as f:
    dict_list = json.load(f)

dict_list
# Out:
# [{u'addr': u'\u548c\u6da6\u5bb6\u56ed\uff08\u522b\u5885\uff09',
#   u'build_face': None,
#   u'district': u'\u95f5\u884c',
#   u'floor_position': None,
#   u'living_room_num': 4,
#   u'name': u'\u4e2d\u7b49\u88c5\u4fee\uff0c\u6ee15\u5e74\uff0c\u968f\u65f6\u53ef\u770b\uff0c\u706b\u7206\u70ed\u9500',
#   u'price': u'1400',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 200.73,
#   u'total_floor': None,
#   u'town': u'\u53e4\u7f8e',
#   u'year': 2004},
#  {u'addr': u'\u767e\u8272\u8def133\u5f04\u5c0f\u533a',
#   u'build_face': u'\u5357',
#   u'district': u'\u5f90\u6c47',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 1,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u9ad8\u533a\u666f\u89c2\u623f\uff0c\u7b80\u5355\u88c5\u4fee',
#   u'price': u'320',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 46.49,
#   u'total_floor': 6,
#   u'town': u'\u690d\u7269\u56ed',
#   u'year': 1995},
#  {u'addr': u'\u4e0a\u6d77\u6e90\u82b1\u57ce',
#   u'build_face': None,
#   u'district': u'\u677e\u6c5f',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u7a00\u7f55\u5357\u5317\u901a\uff0c\u53a8\u536b\u5168\u660e\uff0c\u5149\u7ebf\u5145\u8db3\uff0c\u62ce\u5305\u5165\u4f4f',
#   u'price': u'418',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 105.17,
#   u'total_floor': 17,
#   u'town': u'\u4e5d\u4ead',
#   u'year': 2006},
#  {u'addr': u'\u8d1d\u6e2f\u5357\u533a',
#   u'build_face': u'\u5357',
#   u'district': u'\u5949\u8d24',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 2,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u4f4e\u697c\u5c42\uff0c\u7b80\u5355\u88c5\u4fee',
#   u'price': u'202',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 70.37,
#   u'total_floor': 5,
#   u'town': u'\u5357\u6865',
#   u'year': 1994},
#  {u'addr': u'\u534e\u6b23\u5bb6\u56ed',
#   u'build_face': u'\u5357',
#   u'district': u'\u5f90\u6c47',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 1,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u4f4e\u533a\u51fa\u5165\u65b9\u4fbf\uff0c\u6bdb\u576f\u623f',
#   u'price': u'252',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 44.05,
#   u'total_floor': 6,
#   u'town': u'\u534e\u6cfe',
#   u'year': 2004},
#  {u'addr': u'\u4fdd\u5229\u53f6\u4e0a\u6d77\uff08\u4e00\u671f\uff09',
#   u'build_face': u'\u5357',
#   u'district': u'\u5b9d\u5c71',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 2,
#   u'name': u'\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u5ba2\u5385\u671d\u5357\uff0c\u91c7\u5149\u65e0\u906e\u6321\uff0c\u7cbe\u88c5\u4fee',
#   u'price': u'408',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 80.22,
#   u'total_floor': 27,
#   u'town': u'\u987e\u6751',
#   u'year': 2010},
#  {u'addr': u'\u9e4f\u6d77\u5c0f\u533a',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 1,
#   u'name': u'\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u5367\u5ba4\u5168\u5357\uff0c\u89c6\u91ce\u5f88\u597d\uff0c\u88c5\u4fee\u7cbe\u81f4',
#   u'price': u'290',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 47.0,
#   u'total_floor': 6,
#   u'town': u'\u5317\u8521',
#   u'year': 1997},
#  {u'addr': u'\u7eff\u6d32\u9999\u5c9b\u82b1\u56ed',
#   u'build_face': u'\u5357',
#   u'district': u'\u677e\u6c5f',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 3,
#   u'name': u'\u5357\u5317\u6237\u578b\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u9ec4\u91d1\u697c\u5c42\uff0c\u54c1\u8d28\u88c5\u4fee',
#   u'price': u'690',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 148.3,
#   u'total_floor': 16,
#   u'town': u'\u8398\u95f5\u522b\u5885',
#   u'year': 2010},
#  {u'addr': u'\u8361\u6e7e\u65b0\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u5149\u7ebf\u5145\u8db3\uff0c\u4e2d\u7b49\u88c5\u4fee',
#   u'price': u'180',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 50.89,
#   u'total_floor': 5,
#   u'town': u'\u60e0\u5357',
#   u'year': 1985},
#  {u'addr': u'\u901a\u6cb3\u4e03\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u5b9d\u5c71',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u7a00\u7f3a\u5357\u5317\u901a\uff0c\u53a8\u536b\u5168\u660e\uff0c\u9ec4\u91d1\u697c\u5c42\uff0c\u54c1\u8d28\u88c5\u4fee',
#   u'price': u'350',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 70.97,
#   u'total_floor': 6,
#   u'town': u'\u901a\u6cb3',
#   u'year': 1995},
#  {u'addr': u'\u957f\u6865\u4e94\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u5f90\u6c47',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 2,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u89c6\u91ce\u5f00\u9614\uff0c\u7b80\u5355\u88c5\u4fee',
#   u'price': u'430',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 55.47,
#   u'total_floor': 6,
#   u'town': u'\u957f\u6865',
#   u'year': 1990},
#  {u'addr': u'\u7eff\u5730\u5a01\u5ec9\u516c\u5bd3',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 2,
#   u'name': u'\u5357\u5317\u901a\uff0c\u5ba2\u5385\u671d\u5357\uff0c\u4e0a\u4e0b\u697c\u65b9\u4fbf\uff0c\u54c1\u8d28\u88c5\u4fee',
#   u'price': u'560',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 87.0,
#   u'total_floor': 14,
#   u'town': u'\u9ad8\u884c',
#   u'year': 2005},
#  {u'addr': u'\u89e3\u653e\u65b0\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u5949\u8d24',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u5149\u7ebf\u5145\u8db3\uff0c\u7b80\u5355\u88c5\u4fee\uff0c\u6ee1\u4e94\u51cf\u7a0e\uff0c\u968f\u65f6\u770b\u623f',
#   u'price': u'157',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 56.16,
#   u'total_floor': 6,
#   u'town': u'\u5357\u6865',
#   u'year': 1981},
#  {u'addr': u'\u66d9\u5149\u5317\u82d1',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 3,
#   u'name': u'\u623f\u578b\u6b63\u6c14\uff0c\u5ba2\u5385\u671d\u5357\uff0c\u4f4e\u697c\u5c42\uff0c\u4e2d\u7b49\u88c5\u4fee',
#   u'price': u'555',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 136.86,
#   u'total_floor': 11,
#   u'town': u'\u5ddd\u6c99',
#   u'year': 2004},
#  {u'addr': u'\u4e5d\u534e\u82d1',
#   u'build_face': u'\u5357',
#   u'district': u'\u5949\u8d24',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 3,
#   u'name': u'\u5357\u5317\u76f4\u901a\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u9ec4\u91d1\u697c\u5c42\uff0c\u7b80\u5355\u88c5\u4fee',
#   u'price': u'280',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 88.6,
#   u'total_floor': 6,
#   u'town': u'\u5357\u6865',
#   u'year': 2003},
#  {u'addr': u'\u5171\u5eb7\u4e09\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u95f8\u5317',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 1,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u9ad8\u533a\u9633\u5149\u623f\uff0c\u7701\u88c5\u4fee\u8d39',
#   u'price': u'189',
#   u'price_unit': u'\u4e07',
#   u'room_num': 0,
#   u'size': 35.39,
#   u'total_floor': 6,
#   u'town': u'\u5f6d\u6d66',
#   u'year': 1995},
#  {u'addr': u'\u6d77\u97f5\u99a8\u82d1',
#   u'build_face': u'\u5357',
#   u'district': u'\u5949\u8d24',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 2,
#   u'name': u'\u7a00\u7f55\u5357\u5317\u901a\uff0c\u5e26\u98d8\u7a97\uff0c\u4f4e\u697c\u5c42\uff0c\u7cbe\u88c5\u4fee',
#   u'price': u'190',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 106.53,
#   u'total_floor': 14,
#   u'town': u'\u67d8\u6797',
#   u'year': 2009},
#  {u'addr': u'\u83ca\u6cc9\u65b0\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u5b9d\u5c71',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 1,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u4f4e\u697c\u5c42\uff0c\u7b80\u5355\u88c5\u4fee',
#   u'price': u'200',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 51.0,
#   u'total_floor': 6,
#   u'town': u'\u987e\u6751',
#   u'year': 1995},
#  {u'addr': u'\u5929\u548c\u6e56\u6ee8\u5bb6\u56ed',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 3,
#   u'name': u'\u623f\u578b\u6b63\u6c14\uff0c\u5e26\u98d8\u7a97\uff0c\u4f4e\u533a\u51fa\u5165\u65b9\u4fbf\uff0c\u6bdb\u576f\u623f',
#   u'price': u'435',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 111.13,
#   u'total_floor': 13,
#   u'town': u'\u5ddd\u6c99',
#   u'year': 2010},
#  {u'addr': u'\u53e4\u534eA\u533a',
#   u'build_face': u'\u5357',
#   u'district': u'\u5949\u8d24',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 2,
#   u'name': u'\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u4f4e\u697c\u5c42\uff0c\u7cbe\u88c5\u4fee\uff0c\u6ee15\u5e74',
#   u'price': u'199',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 61.89,
#   u'total_floor': 5,
#   u'town': u'\u5357\u6865',
#   u'year': 1993},
#  {u'addr': u'\u6885\u9647\u4e94\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u5f90\u6c47',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u9ec4\u91d1\u697c\u5c42\uff0c\u4e2d\u7b49\u88c5\u4fee',
#   u'price': u'400',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 71.38,
#   u'total_floor': 18,
#   u'town': u'\u534e\u4e1c\u7406\u5de5',
#   u'year': 1995},
#  {u'addr': u'\u7eff\u5730\u5a01\u5ec9\u516c\u5bd3',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 1,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5ba2\u5385\u671d\u5357\uff0c\u4f4e\u697c\u5c42\uff0c\u54c1\u8d28\u88c5\u4fee',
#   u'price': u'410',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 65.02,
#   u'total_floor': 16,
#   u'town': u'\u9ad8\u884c',
#   u'year': 2005},
#  {u'addr': u'\u7530\u56ed\u522b\u5885\uff08\u522b\u5885\uff09',
#   u'build_face': None,
#   u'district': u'\u957f\u5b81',
#   u'floor_position': None,
#   u'living_room_num': 6,
#   u'name': u'\u6bdb\u576f\u623f\uff0c\u6ee1\u4e94\u51cf\u7a0e\uff0c\u6709\u94a5\u5319\uff0c\u70ed\u9500\u597d\u623f',
#   u'price': u'2000',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 232.8,
#   u'total_floor': None,
#   u'town': u'\u897f\u90ca',
#   u'year': 1995},
#  {u'addr': u'\u56db\u5b63\u7eff\u57ce',
#   u'build_face': u'\u5357',
#   u'district': u'\u5b9d\u5c71',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 2,
#   u'name': u'\u5357\u5317\u6237\u578b\uff0c\u4e0a\u4e0b\u697c\u65b9\u4fbf\uff0c\u6bdb\u576f\u623f\uff0c\u6ee15\u5e74',
#   u'price': u'510',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 90.24,
#   u'total_floor': 14,
#   u'town': u'\u9ad8\u5883',
#   u'year': 2009},
#  {u'addr': u'\u90fd\u5e02\u5bcc\u82d1',
#   u'build_face': u'\u5357',
#   u'district': u'\u95f5\u884c',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 3,
#   u'name': u'\u4e0a\u4e0b\u697c\u65b9\u4fbf\uff0c\u6bdb\u576f\u623f\uff0c\u6ee1\u4e94\u51cf\u7a0e\uff0c\u770b\u623f\u65b9\u4fbf',
#   u'price': u'335',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 130.53,
#   u'total_floor': 11,
#   u'town': u'\u989b\u6865',
#   u'year': 2011},
#  {u'addr': u'\u5408\u751f\u6c5f\u6e7e\u56fd\u9645\u516c\u5bd3',
#   u'build_face': u'\u5357',
#   u'district': u'\u6768\u6d66',
#   u'floor_position': u'\u4f4e',
#   u'living_room_num': 2,
#   u'name': u'\u53a8\u536b\u5168\u660e\uff0c\u5ba2\u5385\u671d\u5357\uff0c\u4f4e\u697c\u5c42\uff0c\u54c1\u8d28\u88c5\u4fee',
#   u'price': u'730',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 96.26,
#   u'total_floor': 11,
#   u'town': u'\u65b0\u6c5f\u6e7e\u57ce',
#   u'year': 2007},
#  {u'addr': u'\u6631\u9f99\u5bb6\u56ed',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u7a00\u7f55\u5357\u5317\u901a\uff0c\u5ba2\u5385\u671d\u5357\uff0c\u9ec4\u91d1\u697c\u5c42\uff0c\u6bdb\u576f\u623f',
#   u'price': u'315',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 80.45,
#   u'total_floor': 11,
#   u'town': u'\u5eb7\u6865',
#   u'year': 2006},
#  {u'addr': u'\u9038\u4ed9\u4e8c\u6751',
#   u'build_face': u'\u5357',
#   u'district': u'\u5b9d\u5c71',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 2,
#   u'name': u'\u5357\u5317\u901a\u900f\uff0c\u5367\u5ba4\u5e26\u9633\u53f0\uff0c\u91c7\u5149\u65e0\u906e\u6321\uff0c\u4e2d\u7b49\u88c5\u4fee',
#   u'price': u'330',
#   u'price_unit': u'\u4e07',
#   u'room_num': 1,
#   u'size': 65.62,
#   u'total_floor': 6,
#   u'town': u'\u9ad8\u5883',
#   u'year': 1996},
#  {u'addr': u'\u91d1\u6c34\u82d1',
#   u'build_face': None,
#   u'district': u'\u5949\u8d24',
#   u'floor_position': u'\u4e2d',
#   u'living_room_num': 2,
#   u'name': u'\u597d\u697c\u5c42\uff0c\u6bdb\u576f\u623f\uff0c\u6ee15\u5e74\uff0c\u6709\u94a5\u5319\u7acb\u5373\u770b',
#   u'price': u'268',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 88.5,
#   u'total_floor': 6,
#   u'town': u'\u5357\u6865',
#   u'year': 2007},
#  {u'addr': u'\u6843\u56ed\u65b0\u57ce\u4e2d\u57ce\u82d1',
#   u'build_face': u'\u5357',
#   u'district': u'\u6d66\u4e1c',
#   u'floor_position': u'\u9ad8',
#   u'living_room_num': 2,
#   u'name': u'\u5357\u5317\u901a\u900f\uff0c\u9ad8\u533a\u91c7\u5149\u597d\uff0c\u88c5\u4fee\u7cbe\u81f4\uff0c\u6ee1\u4e94\u5e74',
#   u'price': u'295',
#   u'price_unit': u'\u4e07',
#   u'room_num': 2,
#   u'size': 72.0,
#   u'total_floor': 5,
#   u'town': u'\u5468\u6d66',
#   u'year': 2006}]

# %%
dist_town_price = pd.DataFrame.from_dict(dict_list)
dist_town_price
# Out:
#          addr build_face district floor_position  living_room_num  \
# 0    和润家园（别墅）       None       闵行           None                4
# 1   百色路133弄小区          南       徐汇              高                1
# 2       上海源花城       None       松江              中                2
# 3        贝港南区          南       奉贤              低                2
# 4        华欣家园          南       徐汇              低                1
# 5   保利叶上海（一期）          南       宝山              高                2
# 6        鹏海小区          南       浦东              高                1
# 7      绿洲香岛花园          南       松江              中                3
# 8        荡湾新村          南       浦东              中                2
# 9        通河七村          南       宝山              中                2
# 10       长桥五村          南       徐汇              高                2
# 11     绿地威廉公寓          南       浦东              低                2
# 12       解放新村          南       奉贤              中                2
# 13       曙光北苑          南       浦东              低                3
# 14        九华苑          南       奉贤              中                3
# 15       共康三村          南       闸北              高                1
# 16       海韵馨苑          南       奉贤              低                2
# 17       菊泉新村          南       宝山              低                1
# 18     天和湖滨家园          南       浦东              低                3
# 19       古华A区          南       奉贤              低                2
# 20       梅陇五村          南       徐汇              中                2
# 21     绿地威廉公寓          南       浦东              中                1
# 22   田园别墅（别墅）       None       长宁           None                6
# 23       四季绿城          南       宝山              低                2
# 24       都市富苑          南       闵行              低                3
# 25   合生江湾国际公寓          南       杨浦              低                2
# 26       昱龙家园          南       浦东              中                2
# 27       逸仙二村          南       宝山              高                2
# 28        金水苑       None       奉贤              中                2
# 29    桃园新城中城苑          南       浦东              高                2
#
#                      name price price_unit  room_num    size  total_floor  \
# 0      中等装修，满5年，随时可看，火爆热销  1400          万         2  200.73          NaN
# 1   厨卫全明，卧室带阳台，高区景观房，简单装修   320          万         1   46.49          6.0
# 2    稀罕南北通，厨卫全明，光线充足，拎包入住   418          万         2  105.17         17.0
# 3     厨卫全明，卧室带阳台，低楼层，简单装修   202          万         1   70.37          5.0
# 4   厨卫全明，卧室带阳台，低区出入方便，毛坯房   252          万         1   44.05          6.0
# 5    卧室带阳台，客厅朝南，采光无遮挡，精装修   408          万         2   80.22         27.0
# 6    卧室带阳台，卧室全南，视野很好，装修精致   290          万         1   47.00          6.0
# 7    南北户型，卧室带阳台，黄金楼层，品质装修   690          万         2  148.30         16.0
# 8    厨卫全明，卧室带阳台，光线充足，中等装修   180          万         1   50.89          5.0
# 9    稀缺南北通，厨卫全明，黄金楼层，品质装修   350          万         2   70.97          6.0
# 10   厨卫全明，卧室带阳台，视野开阔，简单装修   430          万         1   55.47          6.0
# 11    南北通，客厅朝南，上下楼方便，品质装修   560          万         2   87.00         14.0
# 12    光线充足，简单装修，满五减税，随时看房   157          万         1   56.16          6.0
# 13     房型正气，客厅朝南，低楼层，中等装修   555          万         2  136.86         11.0
# 14   南北直通，卧室带阳台，黄金楼层，简单装修   280          万         1   88.60          6.0
# 15  厨卫全明，卧室带阳台，高区阳光房，省装修费   189          万         0   35.39          6.0
# 16      稀罕南北通，带飘窗，低楼层，精装修   190          万         2  106.53         14.0
# 17    厨卫全明，卧室带阳台，低楼层，简单装修   200          万         1   51.00          6.0
# 18    房型正气，带飘窗，低区出入方便，毛坯房   435          万         2  111.13         13.0
# 19      卧室带阳台，低楼层，精装修，满5年   199          万         1   61.89          5.0
# 20   厨卫全明，卧室带阳台，黄金楼层，中等装修   400          万         1   71.38         18.0
# 21     厨卫全明，客厅朝南，低楼层，品质装修   410          万         1   65.02         16.0
# 22      毛坯房，满五减税，有钥匙，热销好房  2000          万         2  232.80          NaN
# 23     南北户型，上下楼方便，毛坯房，满5年   510          万         2   90.24         14.0
# 24    上下楼方便，毛坯房，满五减税，看房方便   335          万         2  130.53         11.0
# 25     厨卫全明，客厅朝南，低楼层，品质装修   730          万         2   96.26         11.0
# 26    稀罕南北通，客厅朝南，黄金楼层，毛坯房   315          万         2   80.45         11.0
# 27  南北通透，卧室带阳台，采光无遮挡，中等装修   330          万         1   65.62          6.0
# 28     好楼层，毛坯房，满5年，有钥匙立即看   268          万         2   88.50          6.0
# 29    南北通透，高区采光好，装修精致，满五年   295          万         2   72.00          5.0
#
#     town  year
# 0     古美  2004
# 1    植物园  1995
# 2     九亭  2006
# 3     南桥  1994
# 4     华泾  2004
# 5     顾村  2010
# 6     北蔡  1997
# 7   莘闵别墅  2010
# 8     惠南  1985
# 9     通河  1995
# 10    长桥  1990
# 11    高行  2005
# 12    南桥  1981
# 13    川沙  2004
# 14    南桥  2003
# 15    彭浦  1995
# 16    柘林  2009
# 17    顾村  1995
# 18    川沙  2010
# 19    南桥  1993
# 20  华东理工  1995
# 21    高行  2005
# 22    西郊  1995
# 23    高境  2009
# 24    颛桥  2011
# 25  新江湾城  2007
# 26    康桥  2006
# 27    高境  1996
# 28    南桥  2007
# 29    周浦  2006
