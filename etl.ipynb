# %%
#-*- encoding:utf-8 -*-
import pandas as pd
import json

# %%
dict_list_file = "data/props.json"
dict_list = None
with open(dict_list_file) as f:
    dict_list = json.load(f)

dict_list
# Out:
# [{u'district': u'\u5f90\u6c47',
#   u'town': u'\u5efa\u56fd\u897f\u8def',
#   u'unit_price': 11.6183185277},
#  {u'district': u'\u9ec4\u6d66',
#   u'town': u'\u65b0\u5929\u5730',
#   u'unit_price': 11.4479018859},
#  {u'district': u'\u9759\u5b89',
#   u'town': u'\u5357\u4eac\u897f\u8def',
#   u'unit_price': 10.999669838},
#  {u'district': u'\u5f90\u6c47',
#   u'town': u'\u8861\u5c71\u8def',
#   u'unit_price': 10.6941398217},
#  {u'district': u'\u9ec4\u6d66',
#   u'town': u'\u5357\u4eac\u4e1c\u8def',
#   u'unit_price': 10.0640752874},
#  {u'district': u'\u9ec4\u6d66',
#   u'town': u'\u6dee\u6d77\u4e2d\u8def',
#   u'unit_price': 9.9716008722},
#  {u'district': u'\u9759\u5b89',
#   u'town': u'\u6c5f\u5b81\u8def',
#   u'unit_price': 9.6372860984},
#  {u'district': u'\u9ec4\u6d66',
#   u'town': u'\u4eba\u6c11\u5e7f\u573a',
#   u'unit_price': 9.5511095869},
#  {u'district': u'\u9ec4\u6d66',
#   u'town': u'\u4e16\u535a\u6ee8\u6c5f',
#   u'unit_price': 9.5062215128},
# ...

# %%
dist_town_price = pd.DataFrame.from_dict(dict_list)
dist_town_price
# Out:
#     district  town  unit_price
# 0         徐汇  建国西路   11.618319
# 1         黄浦   新天地   11.447902
# 2         静安  南京西路   10.999670
# 3         徐汇   衡山路   10.694140
# 4         黄浦  南京东路   10.064075
# 5         黄浦  淮海中路    9.971601
# 6         静安   江宁路    9.637286
# 7         黄浦  人民广场    9.551110
# 8         黄浦  世博滨江    9.506222
# 9         静安   曹家渡    9.493892
# 10        浦东    联洋    9.409471
# 11        徐汇  徐汇滨江    9.408958
# 12        黄浦  蓬莱公园    9.347429
# 13        浦东    碧云    9.298364
# 14        黄浦  黄浦滨江    9.286535
# 15        浦东    潍坊    9.245346
# 16        黄浦    豫园    9.151932
# 17        黄浦   老西门    9.088369
# 18        浦东   陆家嘴    9.061583
# 19        黄浦   董家渡    9.016349
# 20        静安   静安寺    8.976241
# 21        浦东    源深    8.857555
# 22        徐汇   徐家汇    8.789354
# 23        黄浦   五里桥    8.691673
# 24        长宁   镇宁路    8.617344
# 25        长宁    古北    8.609111
# 26        虹口   临平路    8.541810
# 27        黄浦   打浦桥    8.524222
# 28        长宁    天山    8.521374
# ...
